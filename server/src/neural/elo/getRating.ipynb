# %%
from elo_calculator import calculate_team_elo

# %%
elo_ratings_RUS_21 = calculate_team_elo(['csv/Russia/2021/output.csv', 'csv/Russia/2021/outputFNL.csv'], [(235, 1600), (236, 1300)], [('csv/Russia/2021/outputKUBOK.csv', (237, 1350))])

# %%
elo_ratings_RUS_21
# Out:
#                    team_name  league  elo_rating  games
# 596   Zenit Saint Petersburg     235     1791.35     32
# 2012               PFC Sochi     235     1732.67     31
# 558           Spartak Moscow     235     1656.30     35
# 621                Krasnodar     235     1632.87     31
# 555              CSKA Moscow     235     1621.49     34
# 1088           Dinamo Moscow     235     1600.82     36
# 1085           Akhmat Grozny     235     1598.82     31
# 597         Lokomotiv Moscow     235     1584.34     31
# 1079          Krylya Sovetov     235     1574.59     31
# 1994                  Khimki     235     1570.16     33
# 779                FC Rostov     235     1565.33     31
# 1084                    Ural     235     1561.70     31
# 2011         Nizhny Novgorod     235     1540.67     32
# 3985          Torpedo Moskva     236     1531.07     40
# 1078                  FC UFA     235     1500.41     33
# 1080                Orenburg     235     1483.95     41
# ...

# %%
elo_ratings_RUS_21.to_csv('csv/Russia/2021/ratingElo2021_2022RFPL.csv', float_format='%.2f')

# %%
elo_rating_RUS_22 = calculate_team_elo(file_paths = ['csv/Russia/2022/RFPL.csv', 'csv/Russia/2022/FNL.csv'], league_ratings = [(235, 1600), (236, 1300)], kubok = [('csv/Russia/2022/KUBOK.csv', (237, 1350))], save_elo = True, previus_data = 'csv/Russia/2021/ratingElo2021_2022RFPL.csv')

# %%
elo_rating_RUS_22
# Out:
#                    team_name  league  elo_rating  games  \
# 596   Zenit Saint Petersburg     235     1831.41     70
# 555              CSKA Moscow     235     1784.20     77
# 597         Lokomotiv Moscow     235     1721.26     70
# 621                Krasnodar     235     1708.12     75
# 558           Spartak Moscow     235     1661.97     76
# 1085           Akhmat Grozny     235     1656.20     69
# 1080                Orenburg     235     1655.26     77
# 779                FC Rostov     235     1618.39     71
# 1084                    Ural     235     1595.18     74
# 1083                   Rubin     236     1589.01     67
# 1079          Krylya Sovetov     235     1573.14     72
# 1993          Fakel Voronezh     235     1549.03     78
# 2006                 Baltika     236     1546.40     74
# 1088           Dinamo Moscow     235     1528.76     76
# 6787     Alaniya Vladikavkaz     236     1513.25     78
# 6822           Rodina Moskva     235     1499.36     36
# ...

# %%
elo_rating_RUS_22.to_csv('csv/Russia/2022/ratingElo2022_2023RFPL.csv', float_format='%.2f')

# %%
elo_rating_RUS_23 = calculate_team_elo(file_paths = ['csv/Russia/2023/RFPL.csv', 'csv/Russia/2023/FNL.csv'], league_ratings = [(235, 1600), (236, 1300)], kubok = [('csv/Russia/2023/KUBOK.csv', (237, 1350))], save_elo = True, previus_data = 'csv/Russia/2022/ratingElo2022_2023RFPL.csv')

# %%
elo_rating_RUS_23
# Out:
#                    team_name  league  elo_rating  games  \
# 596   Zenit Saint Petersburg     235     1785.06     95
# 621                Krasnodar     235     1767.89     99
# 597         Lokomotiv Moscow     235     1745.50     95
# 1088           Dinamo Moscow     235     1741.87    101
# 555              CSKA Moscow     235     1719.20    102
# 558           Spartak Moscow     235     1660.56    101
# 1083                   Rubin     235     1633.26     91
# 779                FC Rostov     235     1607.62     96
# 1079          Krylya Sovetov     235     1593.28     96
# 1993          Fakel Voronezh     235     1575.45    102
# 1080                Orenburg     235     1574.19    102
# 1085           Akhmat Grozny     235     1559.55     93
# 2006                 Baltika     235     1525.92     99
# 2011         Nizhny Novgorod     235     1525.80     95
# 1084                    Ural     235     1518.96     98
# 1994                  Khimki     236     1502.99     88
# ...

# %%
elo_rating_RUS_23.to_csv('csv/Russia/2023/ratingElo2023_2024RFPL.csv', float_format='%.2f')

# %%
elo_ratings_eng_21 = calculate_team_elo(['csv/England/2021/PL.csv', 'csv/England/2021/championship.csv'], [(39, 1830), (40, 1620)], [('csv/England/2021/cup.csv', (45, 1700)),('csv/England/2021/carabao.csv', (48, 1700))])

# %%
elo_ratings_eng_21
# Out:
#               team_name  league  elo_rating  games
# 40            Liverpool      39     2147.50     49
# 50      Manchester City      39     2110.49     43
# 49              Chelsea      39     2010.71     48
# 47            Tottenham      39     1959.29     45
# 42              Arsenal      39     1944.24     43
# 34            Newcastle      39     1897.20     39
# 52       Crystal Palace      39     1882.12     43
# 51             Brighton      39     1857.50     43
# 46            Leicester      39     1849.07     43
# 65    Nottingham Forest      40     1845.16     54
# 33    Manchester United      39     1843.21     41
# 48             West Ham      39     1816.12     43
# 66          Aston Villa      39     1805.62     40
# 35          Bournemouth      40     1804.42     47
# 55            Brentford      39     1802.34     41
# 36               Fulham      40     1756.96     50
# 37         Huddersfield      40     1756.54     53
# ...

# %%
elo_ratings_eng_21.to_csv('csv/England/2021/ratingElo2021_2022PL.csv', float_format='%.2f')

# %%
elo_ratings_eng_22 = calculate_team_elo(file_paths = ['csv/England/2022/PL.csv', 'csv/England/2022/championship.csv'],  league_ratings = [(39, 1830), (40, 1620)], kubok = [('csv/England/2022/cup.csv', (45, 1700)),('csv/England/2022/carabao.csv', (48, 1700))], save_elo = True, previus_data = 'csv/England/2021/ratingElo2021_2022PL.csv')

# %%
elo_ratings_eng_22
# Out:
#               team_name  league  elo_rating  games  \
# 50      Manchester City      39     2161.08     90
# 40            Liverpool      39     2038.94     91
# 42              Arsenal      39     2015.40     83
# 33    Manchester United      39     2000.21     90
# 34            Newcastle      39     1983.30     83
# 66          Aston Villa      39     1943.73     79
# 51             Brighton      39     1942.19     86
# 55            Brentford      39     1941.31     80
# 44              Burnley      40     1909.78     90
# 47            Tottenham      39     1906.73     86
# 36               Fulham      39     1853.89     93
# 52       Crystal Palace      39     1829.55     83
# 49              Chelsea      39     1820.68     88
# 48             West Ham      39     1802.36     84
# 62        Sheffield Utd      40     1801.24    102
# 39               Wolves      39     1788.41     85
# 65    Nottingham Forest      39     1770.56     98
# ...

# %%
elo_ratings_eng_22.to_csv('csv/England/2022/ratingElo2022_2023PL.csv', float_format='%.2f')

# %%
elo_ratings_eng_23 = calculate_team_elo(file_paths = ['csv/England/2023/PL.csv', 'csv/England/2023/championship.csv'],  league_ratings = [(39, 1830), (40, 1620)], kubok = [('csv/England/2023/cup.csv', (45, 1700)),('csv/England/2023/carabao.csv', (48, 1700))], save_elo = True, previus_data = 'csv/England/2022/ratingElo2022_2023PL.csv')

# %%
elo_ratings_eng_23
# Out:
#                 team_name  league  elo_rating  games  \
# 50        Manchester City      39     2141.13    107
# 40              Liverpool      39     2089.54    109
# 42                Arsenal      39     2039.80    101
# 66            Aston Villa      39     1990.52     96
# 34              Newcastle      39     1990.11    101
# 47              Tottenham      39     1949.89    103
# 33      Manchester United      39     1942.34    108
# 51               Brighton      39     1931.53    103
# 45                Everton      39     1909.32    101
# 49                Chelsea      39     1905.87    106
# 55              Brentford      39     1902.12     97
# 36                 Fulham      39     1893.95    112
# 48               West Ham      39     1890.90    101
# 35            Bournemouth      39     1866.53    108
# 46              Leicester      40     1823.63    100
# 39                 Wolves      39     1792.29    102
# 52         Crystal Palace      39     1768.19    101
# ...

# %%
elo_ratings_eng_23.to_csv('csv/England/2023/ratingElo2023_2024PL.csv', float_format='%.2f')

# %%
elo_ratings_bundes_21 = calculate_team_elo(['csv/Germany/2021/Bundes.csv', 'csv/Germany/2021/Bundes2.csv'], [(78, 1730), (79, 1520)], [('csv/Germany/2021/DFB.csv', (81, 1600))])

# %%
elo_ratings_bundes_21
# Out:
#                      team_name  league  elo_rating  games
# 157              Bayern Munich      78     1953.68     35
# 173                 RB Leipzig      78     1901.26     39
# 168           Bayer Leverkusen      78     1887.37     35
# 182               Union Berlin      78     1844.41     37
# 165          Borussia Dortmund      78     1842.49     36
# 160                SC Freiburg      78     1807.71     38
# 192                    FC Koln      78     1779.95     36
# 163   Borussia Monchengladbach      78     1751.06     37
# 164               FSV Mainz 05      78     1715.78     36
# 161              VfL Wolfsburg      78     1710.24     34
# 174              FC Schalke 04      79     1705.11     34
# 162              Werder Bremen      79     1700.61     34
# 169        Eintracht Frankfurt      78     1681.14     34
# 170                FC Augsburg      78     1677.18     35
# 176                 VfL BOCHUM      78     1671.27     37
# ...

# %%
elo_ratings_bundes_21.to_csv('csv/Germany/2021/ratingElo2021_2022Bundes.csv', float_format='%.2f')

# %%
elo_ratings_bundes_22 = calculate_team_elo(['csv/Germany/2022/Bundes.csv', 'csv/Germany/2022/Bundes2.csv'], [(78, 1730), (79, 1520)], [('csv/Germany/2022/DFB.csv', (81, 1600))], save_elo = True, previus_data = 'csv/Germany/2021/ratingElo2021_2022Bundes.csv')

# %%
elo_ratings_bundes_22
# Out:
#                      team_name  league  elo_rating  games  \
# 173                 RB Leipzig      78     1976.03     78
# 157              Bayern Munich      78     1968.32     72
# 165          Borussia Dortmund      78     1939.02     73
# 182               Union Berlin      78     1838.98     74
# 168           Bayer Leverkusen      78     1826.51     69
# 160                SC Freiburg      78     1814.15     77
# 169        Eintracht Frankfurt      78     1787.53     73
# 161              VfL Wolfsburg      78     1768.62     70
# 172              VfB Stuttgart      78     1756.33     75
# 192                    FC Koln      78     1738.14     71
# 163   Borussia Monchengladbach      78     1732.50     72
# 164               FSV Mainz 05      78     1714.31     71
# 186               FC St. Pauli      79     1698.85     72
# 180              FC Heidenheim      79     1698.22     70
# 167            1899 Hoffenheim      78     1684.88     72
# ...

# %%
elo_ratings_bundes_22.to_csv('csv/Germany/2022/ratingElo2022_2023Bundes.csv', float_format='%.2f')

# %%
elo_ratings_bundes_23 = calculate_team_elo(['csv/Germany/2023/Bundes.csv', 'csv/Germany/2023/Bundes2.csv'], [(78, 1730), (79, 1520)], [('csv/Germany/2023/DFB.csv', (81, 1600))], save_elo = True, previus_data = 'csv/Germany/2022/ratingElo2022_2023Bundes.csv')
elo_ratings_bundes_23
# Out:
#                      team_name  league  elo_rating  games  \
# 157              Bayern Munich      78     2000.96     85
# 173                 RB Leipzig      78     1959.40     94
# 168           Bayer Leverkusen      78     1957.26     84
# 172              VfB Stuttgart      78     1931.43     91
# 165          Borussia Dortmund      78     1920.33     89
# 169        Eintracht Frankfurt      78     1848.43     87
# 186               FC St. Pauli      79     1768.65     87
# 167            1899 Hoffenheim      78     1755.19     87
# 160                SC Freiburg      78     1750.30     92
# 163   Borussia Monchengladbach      78     1731.66     88
# 161              VfL Wolfsburg      78     1690.70     86
# 182               Union Berlin      78     1670.42     88
# 176                 VfL BOCHUM      78     1661.72     86
# 158         Fortuna Dusseldorf      79     1657.02     86
# 162              Werder Bremen      78     1656.59     83
# ...

# %%
elo_ratings_bundes_23.to_csv('csv/Germany/2023/ratingElo2023_2024Bundes.csv', float_format='%.2f')

# %%
elo_ratings_italy_21 = calculate_team_elo(['csv/Italy/2021/SeriaA.csv', 'csv/Italy/2021/SeriaB.csv'], [(78, 1710), (79, 1500)], [('csv/Italy/2021/KUBOK.csv', (81, 1600))])
elo_ratings_italy_21
# Out:
#             team_name  league  elo_rating  games
# 505             Inter      78     1955.66     43
# 489          AC Milan      78     1934.99     42
# 492            Napoli      78     1886.95     39
# 496          Juventus      78     1843.47     43
# 487             Lazio      78     1817.16     40
# 497           AS Roma      78     1815.42     40
# 494           Udinese      78     1744.23     41
# 502        Fiorentina      78     1741.98     44
# 504            Verona      78     1718.66     39
# 488          Sassuolo      78     1714.10     40
# 503            Torino      78     1703.09     40
# 499          Atalanta      78     1697.16     40
# 1579            Monza      79     1669.20     43
# 500           Bologna      78     1655.99     39
# 867             Lecce      79     1650.82     41
# 498         Sampdoria      78     1624.20     41
# 511            Empoli      78     1603.29     41
# 520         Cremonese      79     1584.72     39
# ...

# %%
elo_ratings_italy_21.to_csv('csv/Italy/2021/ratingElo2021_2022Italy.csv', float_format='%.2f')
elo_ratings_italy_22 = calculate_team_elo(['csv/Italy/2022/SeriaA.csv', 'csv/Italy/2022/SeriaB.csv'], [(78, 1730), (79, 1520)], [('csv/Italy/2022/KUBOK.csv', (81, 1600))], save_elo = True, previus_data = 'csv/Italy/2021/ratingElo2021_2022Italy.csv')
elo_ratings_italy_22
# Out:
#            team_name  league  elo_rating  games  \
# 492           Napoli      78     1952.45     78
# 505            Inter      78     1945.27     86
# 487            Lazio      78     1920.96     80
# 496         Juventus      78     1875.92     85
# 489         AC Milan      78     1866.70     81
# 502       Fiorentina      78     1813.12     87
# 499         Atalanta      78     1791.97     80
# 500          Bologna      78     1785.29     80
# 503           Torino      78     1764.49     82
# 497          AS Roma      78     1760.18     80
# 1579           Monza      78     1756.70     84
# 512        Frosinone      79     1730.95     78
# 495            Genoa      79     1698.50     82
# 490         Cagliari      79     1693.72     86
# 514      Salernitana      78     1675.35     79
# 511           Empoli      78     1668.81     80
# 494          Udinese      78     1644.27     80
# 488         Sassuolo      78     1639.84     79
# ...

# %%
elo_ratings_italy_22.to_csv('csv/Italy/2022/ratingElo2022_2023Italy.csv', float_format='%.2f')

# %%
elo_ratings_italy_23 = calculate_team_elo(['csv/Italy/2023/SeriaA.csv', 'csv/Italy/2023/SeriaB.csv'], [(78, 1730), (79, 1520)], [('csv/Italy/2023/KUBOK.csv', (81, 1600))], save_elo = True, previus_data = 'csv/Italy/2022/ratingElo2022_2023Italy.csv')
elo_ratings_italy_23
# Out:
#          team_name  league  elo_rating  games  \
# 505          Inter      78     2014.04    101
# 496       Juventus      78     1948.02    100
# 492         Napoli      78     1909.95     93
# 489       AC Milan      78     1903.93     96
# 487          Lazio      78     1897.46     96
# 502     Fiorentina      78     1850.03    103
# 500        Bologna      78     1849.49     96
# 497        AS Roma      78     1821.90     95
# 499       Atalanta      78     1800.47     95
# 503         Torino      78     1760.64     99
# 1579         Monza      78     1746.30    100
# 523          Parma      79     1737.71     99
# 512      Frosinone      78     1729.88     95
# 490       Cagliari      78     1671.13    103
# 517        Venezia      79     1658.85     96
# 495          Genoa      78     1658.61    100
# 520      Cremonese      79     1642.43     98
# 488       Sassuolo      78     1638.23     96
# 867          Lecce      78     1633.65     97
# ...

# %%
elo_ratings_italy_23.to_csv('csv/Italy/2023/ratingElo2023_2024Italy.csv', float_format='%.2f')
